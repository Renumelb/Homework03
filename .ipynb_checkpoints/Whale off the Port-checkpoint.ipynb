# %% [markdown]
# This assignment will use what I have learnt in Fintech Boot Camp to evaluate the performance of algorithimic, hedge and mutual funds and compare these against the S & P 500 index.
#
# Steps:
# 1. Import the files using pandas
# 2. Cleanse the files for null values and fix data issues
# 3. Calculate the daily returns for S & P 500 index
# 4. Create a dataframe for the returns (Whale returns, Algorithimic snd S & P 500 returns)
# 5. Conduct performance analysis for the portfolio- draw graphs
# 6. Conduct risk analysis for the portfolio- calculate standard deviation
# 7. Calculate Rolling Statistics, coorelation and beta
# 8. Calculate Sharpe ratios
# 9. Create a custom portfolio (Google and AAPL)
# 10. Calculate the weighted retuns for the custom portfolio
# 11. Compare custom portfolio returns with other portfolio
# 12. Conduct risk analysis of custom portfolio
# 13. Analyse custom portfolio performance

# %%
#1. IMPORT CSV FILES USING PANDAS- whale_returns.csv, algo_returns_csv and sp500_history.csv
import pandas as pd
from pathlib import Path
# Read whale_returns.csv
whale_returns_csv = Path('c:/Users/User/Documents/Renu/Homework03/whale_returns.csv')
whale_returns = pd.read_csv(whale_returns_csv, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
whale_returns.sort_index(ascending = True, inplace = True)
whale_returns.head()
# Read algo_returns.csv
algo_returns_csv = Path('c:/Users/User/Documents/Renu/Homework03/algo_returns.csv')
algo_returns = pd.read_csv(algo_returns_csv, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
algo_returns.sort_index(ascending = True, inplace = True)
algo_returns.head()
# Read sp500_history.csv
sp500_history_csv = Path('c:/Users/User/Documents/Renu/Homework03/sp500_history.csv')
sp500_history = pd.read_csv(sp500_history_csv, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
sp500_history.sort_index(ascending = True, inplace = True)
sp500_history.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
#2. CLEANSE THE DATA- whale_returns, algo_returns and sp500_history
#detect null values whale_returns
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
#detect null values algo_returns
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
#detect null values sp500_history
sp500_history.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# drop nulls in whale_returns and reconfirm
whale_ret_clean = whale_returns.dropna()
whale_ret_clean.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# drop nulls in algo_returns and reconfirm
algo_ret_clean = algo_returns.dropna()
algo_ret_clean.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
# Cleanse S & P 500 data- sp500_history
# Check data types
sp500_history.describe(include= 'all')
sp500_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# fix data types in S & P 500- sp500_history
sp500_history['Close'] = sp500_history['Close'].replace('$', '', regex = True).astype('float')
sp500_history.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
#Calculate the daily returns for S & P 500 index- sp500_history, drop nulls and rename "Close"column specific to this portfolio
sp500_dailyreturns = sp500_history.pct_change()
sp500_dailyreturns.isnull().sum()
sp500_dailyreturns.dropna()
sp500_column = ["SP500 Close"]
sp500_dailyreturns.columns = sp500_column
sp500_dailyreturns.head()
# Out:
#             SP500 Close
# Date
# 2012-10-01          NaN
# 2012-10-02     0.000872
# 2012-10-03     0.003624
# 2012-10-04     0.007174
# 2012-10-05    -0.000322

# %%
#4. Create a dataframe for the returns (Whale returns- whale_ret_clean, Algorithimic- algo_ret_clean snd S & P 500 returns- sp500_dailyreturns)
combinedret_df = pd.concat([whale_ret_clean,algo_ret_clean,sp500_dailyreturns], axis ="columns", join = 'inner')
combinedret_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500 Close
# Date
# 2015-03-03 -0.000949    -0.004539
# 2015-03-04  0.002416    -0.004389
# 2015-03-05  0.004323     0.001196
# 2015-03-06 -0.011460    -0.014174
# 2015-03-09  0.001303     0.003944

# %%
#5. Conduct performance analysis of the combined portfolio- combinedret_df
# calculate and plot daily returns of all portfolios
combinedret_df.plot(figsize = (25, 15))
# Note that Tiger Global seem sto have quite a few spikes aka seems volatile
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# calculate and plot cumulative returns of all portfolios
cumret_df = (1+combinedret_df).cumprod()
cumret_df.plot(figsize = (25,10))
# Note: Algo 1 and Berkshire Hathaway generally outperform the S & P 500.
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#6. Conduct risk analysis- cumret_df
# Create a box plot for each of the returns
cumret_df.plot(kind='box', figsize = (25,10))
# Out:
# <AxesSubplot:>

# %%
# Calculate the standard deviation for each portfolio
combinedret_df.std()
#Note: The portfolios that have the largest standard deviation values from that of S & P 500 are the riskiest aka Tiger Global and Berkshire Hathaway
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP500 Close                    0.008554
# dtype: float64

# %%
# Calculate the annualised standard deviation for each portfolio
import numpy as np
combinedret_df.std()*np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# SP500 Close                    0.135786
# dtype: float64

# %%
#7. Calculate Rolling Statistics for each portfolio
roll21stats = combinedret_df.rolling(window = 21).std()
roll21stats.tail(25)# to reconfirm
roll21stats.plot(figsize = (25,10), title = 'Rolling 21 day standard deviation')
# Out:
# <AxesSubplot:title={'center':'Rolling 21 day standard deviation'}, xlabel='Date'>

# %%
# Calculate the corelation
combinedret_cor = combinedret_df.corr()
combinedret_cor.head(7)
#Note: Based on below matrix Algo 2 best mimicks the S & P 500- highest coorelation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# SP500 Close                                   0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# SP500 Close                                     0.623946
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# SP500 Close                                0.751371  0.279494  0.858764
#
#                              SP500 Close
# SOROS FUND MANAGEMENT LLC       0.837864
# PAULSON & CO.INC.               0.669732
# TIGER GLOBAL MANAGEMENT LLC     0.623946
# BERKSHIRE HATHAWAY INC          0.751371
# Algo 1                          0.279494
# Algo 2                          0.858764
# SP500 Close                     1.000000

# %%
#Calculate and plot the 60 day rolling beta for a chosen portfolio and the S & P 500
covariance_Algo2_60 = combinedret_df['Algo 2'].rolling(window = 60).cov(combinedret_df['SP500 Close'])
variance_60 = combinedret_df['SP500 Close'].rolling(window = 60).var()
beta_algo2_60 = variance_60 / covariance_Algo2_60
beta_algo2_60.plot(figsize = (20,10), title = 'Rolling 60 day Beta of Algo 2')
# Out:
# <AxesSubplot:title={'center':'Rolling 60 day Beta of Algo 2'}, xlabel='Date'>

# %%
# 8. Calculate annualised Sharpe ratios
combined_sharpe = combinedret_df.mean()*252/(combinedret_df.std()*np.sqrt(252))
combined_sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP500 Close                    0.648267
# dtype: float64

# %%
combined_sharpe.plot(kind = 'bar', figsize = (25, 10), title = 'Sharpe ratios for the portfolio')
#Note: Based on below, Algo 1 has definitely outperformed the market and whales portfolio but the same cannot be said of Algo 2
# Out:
# <AxesSubplot:title={'center':'Sharpe ratios for the portfolio'}>
